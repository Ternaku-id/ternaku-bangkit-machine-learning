# %%
import os
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
import seaborn as sns

# %%
#pinkey cow
folder_path = (r'D:\Kampus Merdeka\Documentation\Cow\train\Pinkeye Cow')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#healthy cow
folder_path = (r'D:\Kampus Merdeka\Documentation\Cow\train\Healthy Cow')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#cek label
image_dir = Path(r'D:\Kampus Merdeka\Documentation\Cow\train')

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index
image_df = image_df.sample(frac=1).reset_index(drop = True)

# Show the result
image_df.head(2)
# Out:
#                                             Filepath        Label
# 0  D:\Kampus Merdeka\Documentation\Cow\train\Heal...  Healthy Cow
# 1  D:\Kampus Merdeka\Documentation\Cow\train\Pink...  Pinkeye Cow

# %%
# Display some pictures of the dataset with their labels

fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[i]))
    ax.set_title(image_df.Label[i])
plt.tight_layout()
plt.show()

# %%
#Shuffle
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
# Separate in train and test data
train_df, validasi_df = train_test_split(image_df, train_size=0.8, shuffle=True, random_state=1)

# %%
from keras import Model, Input
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
from keras import layers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
import numpy as np
# %matplotlib inline

# %%
input_shape = (180,180,3)
model_input = Input(shape=input_shape)

mobileNet = MobileNetV2(input_shape=input_shape, 
                        input_tensor=model_input, 
                        include_top=False, 
                        weights="imagenet")

for layer in mobileNet.layers:
    layer.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
#data generator
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest',
    brightness_range=[0.8, 1.2],
    horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)
                                   
train_data = train_datagen.flow_from_dataframe(dataframe=train_df,
                                          x_col='Filepath',
                                          y_col='Label',
                                         seed=0,
                                         target_size=(180,180),
                                         batch_size=16,
                                         shuffle=True,
                                         class_mode = 'categorical',
                                        subset='training',
                                         )

validasi_data = val_datagen.flow_from_dataframe(dataframe=validasi_df,
                                        x_col='Filepath',
                                        y_col='Label',
                                         seed=0,
                                         target_size=(180,180),
                                         batch_size=16,
                                         shuffle=False,
                                         class_mode = 'categorical',
                                         )
# Out:
# Found 435 validated image filenames belonging to 2 classes.
# Found 109 validated image filenames belonging to 2 classes.

# %%
x_mobileNet = mobileNet.output
# Flatten 
x_mobileNet = Flatten()(x_mobileNet)
# Add a fully connected layer with 512 hidden units and ReLU activation
x_mobileNet = Dense(512, activation='relu')(x_mobileNet)
# Add a dropout rate of 0.5
x_mobileNet = Dropout(0.2)(x_mobileNet)
# Add a final softmax layer for classification
x_mobileNet = Dense(2, activation='softmax')(x_mobileNet)

# Configure and compile the model
mobileNet_model = Model(model_input, x_mobileNet)
optimizer = Adam(lr=1e-5)
mobileNet_model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# C:\Users\Fenny Puspitasari\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# ModelCheckpoint callback
checkpoint_callback = ModelCheckpoint('MobileNet_Cow_model_best.h5',
                                      save_best_only=True,
                                      monitor='val_loss',
                                      mode='min', verbose=1)

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss') < 0.1 and logs.get('val_loss') < 0.1):
      print("\Stopped, Akurasi mencapai 98%")
      self.model.stop_training = True;

# %%
callbacks = myCallback()

# Fit the model
history_mobileNet = mobileNet_model.fit(
    train_data,
    validation_data=validasi_data,
    steps_per_epoch=train_data.n//16,
    validation_steps=validasi_data.n//16,
    epochs=50,
    callbacks=[callbacks, checkpoint_callback])
# Out:
# Epoch 1/50
# 27/27 [==============================] - ETA: 0s - loss: 0.8399 - accuracy: 0.7112
# Epoch 1: val_loss improved from inf to 0.39617, saving model to MobileNet_Cow_model_best.h5
# 27/27 [==============================] - 17s 556ms/step - loss: 0.8399 - accuracy: 0.7112 - val_loss: 0.3962 - val_accuracy: 0.8333
# Epoch 2/50
# 27/27 [==============================] - ETA: 0s - loss: 0.5001 - accuracy: 0.8043
# Epoch 2: val_loss improved from 0.39617 to 0.30565, saving model to MobileNet_Cow_model_best.h5
# 27/27 [==============================] - 14s 501ms/step - loss: 0.5001 - accuracy: 0.8043 - val_loss: 0.3056 - val_accuracy: 0.8542
# Epoch 3/50
# 27/27 [==============================] - ETA: 0s - loss: 0.4983 - accuracy: 0.8115
# Epoch 3: val_loss improved from 0.30565 to 0.28662, saving model to MobileNet_Cow_model_best.h5
# 27/27 [==============================] - 13s 481ms/step - loss: 0.4983 - accuracy: 0.8115 - val_loss: 0.2866 - val_accuracy: 0.8125
# Epoch 4/50
# 27/27 [==============================] - ETA: 0s - loss: 0.3575 - accuracy: 0.8735
# Epoch 4: val_loss did not improve from 0.28662
# 27/27 [==============================] - 12s 435ms/step - loss: 0.3575 - accuracy: 0.8735 - val_loss: 0.2904 - val_accuracy: 0.8438
# Epoch 5/50
# 27/27 [==============================] - ETA: 0s - loss: 0.4149 - accuracy: 0.8473
# Epoch 5: val_loss improved from 0.28662 to 0.27690, saving model to MobileNet_Cow_model_best.h5
# 27/27 [==============================] - 14s 530ms/step - loss: 0.4149 - accuracy: 0.8473 - val_loss: 0.2769 - val_accuracy: 0.8958
# Epoch 6/50
# 27/27 [==============================] - ETA: 0s - loss: 0.3500 - accuracy: 0.8687
# Epoch 6: val_loss improved from 0.27690 to 0.15916, saving model to MobileNet_Cow_model_best.h5
# 27/27 [==============================] - 13s 488ms/step - loss: 0.3500 - accuracy: 0.8687 - val_loss: 0.1592 - val_accuracy: 0.8958
# Epoch 7/50
# 27/27 [==============================] - ETA: 0s - loss: 0.2889 - accuracy: 0.8866
# Epoch 7: val_loss improved from 0.15916 to 0.15425, saving model to MobileNet_Cow_model_best.h5
# 27/27 [==============================] - 13s 481ms/step - loss: 0.2889 - accuracy: 0.8866 - val_loss: 0.1543 - val_accuracy: 0.9062
# Epoch 8/50
# 27/27 [==============================] - ETA: 0s - loss: 0.2472 - accuracy: 0.8902
# Epoch 8: val_loss did not improve from 0.15425
# 27/27 [==============================] - 13s 478ms/step - loss: 0.2472 - accuracy: 0.8902 - val_loss: 0.1721 - val_accuracy: 0.8854
# Epoch 9/50
# 27/27 [==============================] - ETA: 0s - loss: 0.2460 - accuracy: 0.8950
# Epoch 9: val_loss did not improve from 0.15425
# 27/27 [==============================] - 16s 583ms/step - loss: 0.2460 - accuracy: 0.8950 - val_loss: 0.1602 - val_accuracy: 0.9375
# Epoch 10/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1964 - accuracy: 0.9332
# Epoch 10: val_loss did not improve from 0.15425
# 27/27 [==============================] - 14s 501ms/step - loss: 0.1964 - accuracy: 0.9332 - val_loss: 0.1716 - val_accuracy: 0.9271
# Epoch 11/50
# 27/27 [==============================] - ETA: 0s - loss: 0.2613 - accuracy: 0.9189
# Epoch 11: val_loss did not improve from 0.15425
# 27/27 [==============================] - 14s 536ms/step - loss: 0.2613 - accuracy: 0.9189 - val_loss: 0.1638 - val_accuracy: 0.9062
# Epoch 12/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1849 - accuracy: 0.9427
# Epoch 12: val_loss did not improve from 0.15425
# 27/27 [==============================] - 13s 500ms/step - loss: 0.1849 - accuracy: 0.9427 - val_loss: 0.1721 - val_accuracy: 0.9062
# Epoch 13/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1638 - accuracy: 0.9332
# Epoch 13: val_loss did not improve from 0.15425
# 27/27 [==============================] - 13s 463ms/step - loss: 0.1638 - accuracy: 0.9332 - val_loss: 0.1644 - val_accuracy: 0.9271
# Epoch 14/50
# 27/27 [==============================] - ETA: 0s - loss: 0.2295 - accuracy: 0.9141
# Epoch 14: val_loss did not improve from 0.15425
# 27/27 [==============================] - 13s 483ms/step - loss: 0.2295 - accuracy: 0.9141 - val_loss: 0.1650 - val_accuracy: 0.9062
# Epoch 15/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9284
# Epoch 15: val_loss improved from 0.15425 to 0.15122, saving model to MobileNet_Cow_model_best.h5
# 27/27 [==============================] - 14s 536ms/step - loss: 0.1892 - accuracy: 0.9284 - val_loss: 0.1512 - val_accuracy: 0.9062
# Epoch 16/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1584 - accuracy: 0.9356
# Epoch 16: val_loss did not improve from 0.15122
# 27/27 [==============================] - 13s 493ms/step - loss: 0.1584 - accuracy: 0.9356 - val_loss: 0.1531 - val_accuracy: 0.9271
# Epoch 17/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9356
# Epoch 17: val_loss did not improve from 0.15122
# 27/27 [==============================] - 14s 513ms/step - loss: 0.1357 - accuracy: 0.9356 - val_loss: 0.1576 - val_accuracy: 0.9062
# Epoch 18/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9356
# Epoch 18: val_loss did not improve from 0.15122
# 27/27 [==============================] - 14s 513ms/step - loss: 0.1530 - accuracy: 0.9356 - val_loss: 0.1667 - val_accuracy: 0.9062
# Epoch 19/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9403
# Epoch 19: val_loss did not improve from 0.15122
# 27/27 [==============================] - 13s 473ms/step - loss: 0.1401 - accuracy: 0.9403 - val_loss: 0.1863 - val_accuracy: 0.9062
# Epoch 20/50
# 27/27 [==============================] - ETA: 0s - loss: 0.2021 - accuracy: 0.9260
# Epoch 20: val_loss did not improve from 0.15122
# 27/27 [==============================] - 13s 493ms/step - loss: 0.2021 - accuracy: 0.9260 - val_loss: 0.1674 - val_accuracy: 0.9062
# Epoch 21/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9284
# Epoch 21: val_loss did not improve from 0.15122
# 27/27 [==============================] - 13s 480ms/step - loss: 0.1403 - accuracy: 0.9284 - val_loss: 0.1621 - val_accuracy: 0.9062
# Epoch 22/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1675 - accuracy: 0.9475
# Epoch 22: val_loss improved from 0.15122 to 0.13671, saving model to MobileNet_Cow_model_best.h5
# 27/27 [==============================] - 14s 513ms/step - loss: 0.1675 - accuracy: 0.9475 - val_loss: 0.1367 - val_accuracy: 0.9479
# Epoch 23/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9475
# Epoch 23: val_loss did not improve from 0.13671
# 27/27 [==============================] - 12s 458ms/step - loss: 0.1149 - accuracy: 0.9475 - val_loss: 0.1717 - val_accuracy: 0.9062
# Epoch 24/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.9547
# Epoch 24: val_loss did not improve from 0.13671
# 27/27 [==============================] - 12s 451ms/step - loss: 0.1392 - accuracy: 0.9547 - val_loss: 0.1604 - val_accuracy: 0.9167
# Epoch 25/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9475
# Epoch 25: val_loss did not improve from 0.13671
# 27/27 [==============================] - 12s 451ms/step - loss: 0.1148 - accuracy: 0.9475 - val_loss: 0.1584 - val_accuracy: 0.9167
# Epoch 26/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1259 - accuracy: 0.9475
# Epoch 26: val_loss did not improve from 0.13671
# 27/27 [==============================] - 12s 451ms/step - loss: 0.1259 - accuracy: 0.9475 - val_loss: 0.1910 - val_accuracy: 0.9062
# Epoch 27/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9666
# Epoch 27: val_loss improved from 0.13671 to 0.12492, saving model to MobileNet_Cow_model_best.h5
# 27/27 [==============================] - 13s 479ms/step - loss: 0.0910 - accuracy: 0.9666 - val_loss: 0.1249 - val_accuracy: 0.9375
# Epoch 28/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9594
# Epoch 28: val_loss improved from 0.12492 to 0.10325, saving model to MobileNet_Cow_model_best.h5
# 27/27 [==============================] - 13s 471ms/step - loss: 0.1065 - accuracy: 0.9594 - val_loss: 0.1033 - val_accuracy: 0.9583
# Epoch 29/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9618
# Epoch 29: val_loss did not improve from 0.10325
# 27/27 [==============================] - 12s 438ms/step - loss: 0.0948 - accuracy: 0.9618 - val_loss: 0.1139 - val_accuracy: 0.9479
# Epoch 30/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9523
# Epoch 30: val_loss did not improve from 0.10325
# 27/27 [==============================] - 12s 444ms/step - loss: 0.1085 - accuracy: 0.9523 - val_loss: 0.1380 - val_accuracy: 0.9167
# Epoch 31/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9594
# Epoch 31: val_loss did not improve from 0.10325
# 27/27 [==============================] - 12s 453ms/step - loss: 0.0940 - accuracy: 0.9594 - val_loss: 0.1389 - val_accuracy: 0.9062
# Epoch 32/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0625 - accuracy: 0.9761
# Epoch 32: val_loss did not improve from 0.10325
# 27/27 [==============================] - 12s 458ms/step - loss: 0.0625 - accuracy: 0.9761 - val_loss: 0.1340 - val_accuracy: 0.9271
# Epoch 33/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9499
# Epoch 33: val_loss did not improve from 0.10325
# 27/27 [==============================] - 12s 443ms/step - loss: 0.1055 - accuracy: 0.9499 - val_loss: 0.1392 - val_accuracy: 0.9271
# Epoch 34/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9761
# Epoch 34: val_loss did not improve from 0.10325
# 27/27 [==============================] - 12s 443ms/step - loss: 0.0787 - accuracy: 0.9761 - val_loss: 0.1321 - val_accuracy: 0.9062
# Epoch 35/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9785
# Epoch 35: val_loss did not improve from 0.10325
# 27/27 [==============================] - 12s 452ms/step - loss: 0.0674 - accuracy: 0.9785 - val_loss: 0.2222 - val_accuracy: 0.8958
# Epoch 36/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9618
# Epoch 36: val_loss did not improve from 0.10325
# 27/27 [==============================] - 12s 458ms/step - loss: 0.0779 - accuracy: 0.9618 - val_loss: 0.1426 - val_accuracy: 0.9167
# Epoch 37/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1087 - accuracy: 0.9594
# Epoch 37: val_loss improved from 0.10325 to 0.09216, saving model to MobileNet_Cow_model_best.h5
# 27/27 [==============================] - 13s 472ms/step - loss: 0.1087 - accuracy: 0.9594 - val_loss: 0.0922 - val_accuracy: 0.9792
# Epoch 38/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9761
# Epoch 38: val_loss did not improve from 0.09216
# 27/27 [==============================] - 12s 441ms/step - loss: 0.0626 - accuracy: 0.9761 - val_loss: 0.1589 - val_accuracy: 0.9062
# Epoch 39/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9833
# Epoch 39: val_loss did not improve from 0.09216
# 27/27 [==============================] - 12s 458ms/step - loss: 0.0604 - accuracy: 0.9833 - val_loss: 0.1553 - val_accuracy: 0.9062
# Epoch 40/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9666
# Epoch 40: val_loss did not improve from 0.09216
# 27/27 [==============================] - 12s 459ms/step - loss: 0.0677 - accuracy: 0.9666 - val_loss: 0.1286 - val_accuracy: 0.9375
# Epoch 41/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0986 - accuracy: 0.9690
# Epoch 41: val_loss did not improve from 0.09216
# 27/27 [==============================] - 12s 451ms/step - loss: 0.0986 - accuracy: 0.9690 - val_loss: 0.1789 - val_accuracy: 0.9062
# Epoch 42/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9761
# Epoch 42: val_loss did not improve from 0.09216
# 27/27 [==============================] - 12s 445ms/step - loss: 0.0563 - accuracy: 0.9761 - val_loss: 0.1400 - val_accuracy: 0.9375
# Epoch 43/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9714
# Epoch 43: val_loss did not improve from 0.09216
# 27/27 [==============================] - 12s 446ms/step - loss: 0.0648 - accuracy: 0.9714 - val_loss: 0.1309 - val_accuracy: 0.9375
# Epoch 44/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1006 - accuracy: 0.9714
# Epoch 44: val_loss did not improve from 0.09216
# 27/27 [==============================] - 12s 454ms/step - loss: 0.1006 - accuracy: 0.9714 - val_loss: 0.1209 - val_accuracy: 0.9583
# Epoch 45/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0842 - accuracy: 0.9547
# Epoch 45: val_loss did not improve from 0.09216
# 27/27 [==============================] - 12s 449ms/step - loss: 0.0842 - accuracy: 0.9547 - val_loss: 0.1021 - val_accuracy: 0.9583
# Epoch 46/50
# 27/27 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9642
# Epoch 46: val_loss improved from 0.09216 to 0.07518, saving model to MobileNet_Cow_model_best.h5
# 27/27 [==============================] - 13s 472ms/step - loss: 0.1081 - accuracy: 0.9642 - val_loss: 0.0752 - val_accuracy: 0.9583
# Epoch 47/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9809\Stopped, Akurasi mencapai 98%
#
# Epoch 47: val_loss did not improve from 0.07518
# 27/27 [==============================] - 12s 460ms/step - loss: 0.0719 - accuracy: 0.9809 - val_loss: 0.0764 - val_accuracy: 0.9583

# %%
train_accuracy = history_mobileNet.history['accuracy']
val_accuracy = history_mobileNet.history['val_accuracy']
train_loss = history_mobileNet.history['loss']
val_loss= history_mobileNet.history['val_loss']

plt.figure(figsize=(16, 8))

# Cek hasil akurasi
plt.subplot(1, 2, 1)
plt.plot(train_accuracy, label='Training Accuracy', color='#185fad')
plt.plot(val_accuracy, label='Validation Accuracy', color='orange')

plt.title('Training and Validation Accuracy by Epoch', fontsize = 18)
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Mean-Square-Error', fontsize = 18)
plt.xticks(range(0,16,20), range(0,16,20))

plt.legend(fontsize = 18);

plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Training Loss', color='#185fad')
plt.plot(val_loss, label='Validation Loss', color='orange')

plt.title('Training and Validation Loss by Epoch', fontsize = 18)
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Mean-Square-Error', fontsize = 18)
plt.xticks(range(0,16,20), range(0,16,20))


plt.legend(fontsize = 18)

# %%
#Plot the confusion matrix. Set Normalize = True/False

def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(20,20))

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

#Print the Target names
from sklearn.metrics import classification_report, confusion_matrix
import itertools 
#shuffle=False

target_names = []
for key in validasi_data.class_indices:
    target_names.append(key)

# print(target_names)

#Confution Matrix 

Y_pred = mobileNet_model.predict_generator(validasi_data)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm = confusion_matrix(validasi_data.classes, y_pred)
plot_confusion_matrix(cm, target_names, title='Confusion Matrix')

#Print Classification Report
print('Classification Report')
print(classification_report(validasi_data.classes, y_pred, target_names=target_names))
# Out:
# C:\Users\Fenny Puspitasari\AppData\Local\Temp\ipykernel_11360\385079297.py:47: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = mobileNet_model.predict_generator(validasi_data)
# Confusion Matrix
# Normalized confusion matrix
# Classification Report
#               precision    recall  f1-score   support
#
#  Healthy Cow       0.95      0.95      0.95        43
#  Pinkeye Cow       0.97      0.97      0.97        66
#
#     accuracy                           0.96       109
#    macro avg       0.96      0.96      0.96       109
# weighted avg       0.96      0.96      0.96       109

# %%
# Predict the label of the test_images
from tensorflow.keras.models import load_model

# Load the trained model
mobileNet_model = load_model('MobileNet_Cow_model_best.h5')

pred = mobileNet_model.predict(validasi_data)
pred_classes = np.argmax(pred,axis=1)
pred_proba = np.max(pred, axis=1)

# Map the label
labels = (train_data.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred_classes = [labels[k] for k in pred_classes]

# Display the result
print(f'The first 15 predictions: {pred_classes[:15]}')
# Out:
# 7/7 [==============================] - 4s 302ms/step
# The first 15 predictions: ['Pinkeye Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Healthy Cow', 'Pinkeye Cow', 'Healthy Cow', 'Healthy Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Healthy Cow', 'Pinkeye Cow', 'Pinkeye Cow']

# %%
# Display the result
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(20, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(validasi_df.Filepath.iloc[i]))
    ax.set_title(f"True: {validasi_df.Label.iloc[i]}\nPredicted: {pred_classes[i]}\nProbability: {pred_proba[i]:.3f}")
plt.tight_layout()
plt.show()

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_keras_model(mobileNet_model)
tflite_model = converter.convert()

with open('MobileNet_Cow_model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\FENNYP~1\AppData\Local\Temp\tmp9izi2wfv\assets
# INFO:tensorflow:Assets written to: C:\Users\FENNYP~1\AppData\Local\Temp\tmp9izi2wfv\assets
