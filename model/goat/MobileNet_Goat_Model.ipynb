# %%
import os
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
import seaborn as sns

# %%
#pinkey goat
folder_path = (r'D:\Kampus Merdeka\Documentation\Goat\train\Pinkeye Goat')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#healthy goat
folder_path = (r'D:\Kampus Merdeka\Documentation\Goat\train\Healthy Goat')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#cek label
image_dir = Path(r'D:\Kampus Merdeka\Documentation\Goat\train')

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index
image_df = image_df.sample(frac=1).reset_index(drop = True)

# Show the result
image_df.head(2)
# Out:
#                                             Filepath         Label
# 0  D:\Kampus Merdeka\Documentation\Goat\train\Pin...  Pinkeye Goat
# 1  D:\Kampus Merdeka\Documentation\Goat\train\Hea...  Healthy Goat

# %%
# Display some pictures of the dataset with their labels

fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[i]))
    ax.set_title(image_df.Label[i])
plt.tight_layout()
plt.show()

# %%
#Shuffle
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
# Separate in train and test data
train_df, validasi_df = train_test_split(image_df, train_size=0.8, shuffle=True, random_state=1)

# %%
import tensorflow as tf
from keras import Model, Input
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
from keras import layers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
input_shape = (416,416,3)
model_input = Input(shape=input_shape)

mobileNet = MobileNetV2(input_shape=input_shape, 
                        input_tensor=model_input, 
                        include_top=False, 
                        weights="imagenet")

for layer in mobileNet.layers:
    layer.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
#data generator
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest',
    brightness_range=[0.8, 1.2],
    horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)
                                   
train_data = train_datagen.flow_from_dataframe(dataframe=train_df,
                                          x_col='Filepath',
                                          y_col='Label',
                                         seed=0,
                                         target_size=(416,416),
                                         batch_size=16,
                                         shuffle=True,
                                         class_mode = 'categorical',
                                        subset='training',
                                         )

validasi_data = val_datagen.flow_from_dataframe(dataframe=validasi_df,
                                        x_col='Filepath',
                                        y_col='Label',
                                         seed=0,
                                         target_size=(416,416),
                                         batch_size=16,
                                         shuffle=False,
                                         class_mode = 'categorical',
                                         )
# Out:
# Found 476 validated image filenames belonging to 2 classes.
# Found 119 validated image filenames belonging to 2 classes.

# %%
x_mobileNet = mobileNet.output
# Flatten 
x_mobileNet = Flatten(name="flatten")(x_mobileNet)
# Add a fully connected layer with 512 hidden units and ReLU activation
x_mobileNet = Dense(512, activation='relu')(x_mobileNet)
# Add a dropout rate of 0.5
x_mobileNet = Dropout(0.2)(x_mobileNet)
# Add a final softmax layer for classification
x_mobileNet = Dense(2, activation='softmax')(x_mobileNet)

# Configure and compile the model
mobileNet_model = Model(model_input, x_mobileNet)
optimizer = Adam(lr=1e-5)
mobileNet_model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# C:\Users\Fenny Puspitasari\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# ModelCheckpoint callback
checkpoint_callback = ModelCheckpoint('MobileNet_Goat_model_best.h5',
                                      save_best_only=True,
                                      monitor='val_loss',
                                      mode='min', verbose=1)

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss') < 0.1 and logs.get('val_loss') < 0.1):
      print("\Stopped, Akurasi mencapai 98%")
      self.model.stop_training = True;

# %%
callbacks = myCallback()

# Fit the model
history_mobileNet = mobileNet_model.fit(
    train_data,
    validation_data=validasi_data,
    steps_per_epoch=train_data.n//16,
    validation_steps=validasi_data.n//16,
    epochs=50,
    callbacks=[callbacks, checkpoint_callback])
# Out:
# Epoch 1/50
# 29/29 [==============================] - ETA: 0s - loss: 0.9765 - accuracy: 0.6652
# Epoch 1: val_loss improved from inf to 0.50580, saving model to MobileNet_Goat_model_best.h5
# 29/29 [==============================] - 63s 2s/step - loss: 0.9765 - accuracy: 0.6652 - val_loss: 0.5058 - val_accuracy: 0.7768
# Epoch 2/50
# 29/29 [==============================] - ETA: 0s - loss: 0.4911 - accuracy: 0.8233
# Epoch 2: val_loss improved from 0.50580 to 0.24041, saving model to MobileNet_Goat_model_best.h5
# 29/29 [==============================] - 60s 2s/step - loss: 0.4911 - accuracy: 0.8233 - val_loss: 0.2404 - val_accuracy: 0.9107
# Epoch 3/50
# 29/29 [==============================] - ETA: 0s - loss: 0.3371 - accuracy: 0.8717
# Epoch 3: val_loss did not improve from 0.24041
# 29/29 [==============================] - 56s 2s/step - loss: 0.3371 - accuracy: 0.8717 - val_loss: 0.3148 - val_accuracy: 0.8571
# Epoch 4/50
# 29/29 [==============================] - ETA: 0s - loss: 0.3525 - accuracy: 0.8500
# Epoch 4: val_loss improved from 0.24041 to 0.17639, saving model to MobileNet_Goat_model_best.h5
# 29/29 [==============================] - 59s 2s/step - loss: 0.3525 - accuracy: 0.8500 - val_loss: 0.1764 - val_accuracy: 0.9375
# Epoch 5/50
# 29/29 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.8957
# Epoch 5: val_loss did not improve from 0.17639
# 29/29 [==============================] - 58s 2s/step - loss: 0.2782 - accuracy: 0.8957 - val_loss: 0.2142 - val_accuracy: 0.9196
# Epoch 6/50
# 29/29 [==============================] - ETA: 0s - loss: 0.3280 - accuracy: 0.8739
# Epoch 6: val_loss did not improve from 0.17639
# 29/29 [==============================] - 56s 2s/step - loss: 0.3280 - accuracy: 0.8739 - val_loss: 0.2051 - val_accuracy: 0.8929
# Epoch 7/50
# 29/29 [==============================] - ETA: 0s - loss: 0.2956 - accuracy: 0.8804
# Epoch 7: val_loss did not improve from 0.17639
# 29/29 [==============================] - 56s 2s/step - loss: 0.2956 - accuracy: 0.8804 - val_loss: 0.2273 - val_accuracy: 0.9196
# Epoch 8/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1830 - accuracy: 0.9239
# Epoch 8: val_loss improved from 0.17639 to 0.17059, saving model to MobileNet_Goat_model_best.h5
# 29/29 [==============================] - 58s 2s/step - loss: 0.1830 - accuracy: 0.9239 - val_loss: 0.1706 - val_accuracy: 0.9375
# Epoch 9/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9413
# Epoch 9: val_loss did not improve from 0.17059
# 29/29 [==============================] - 56s 2s/step - loss: 0.1593 - accuracy: 0.9413 - val_loss: 0.2085 - val_accuracy: 0.9196
# Epoch 10/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1529 - accuracy: 0.9413
# Epoch 10: val_loss did not improve from 0.17059
# 29/29 [==============================] - 56s 2s/step - loss: 0.1529 - accuracy: 0.9413 - val_loss: 0.2045 - val_accuracy: 0.9196
# Epoch 11/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9565
# Epoch 11: val_loss did not improve from 0.17059
# 29/29 [==============================] - 56s 2s/step - loss: 0.1125 - accuracy: 0.9565 - val_loss: 0.1736 - val_accuracy: 0.9375
# Epoch 12/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1394 - accuracy: 0.9478
# Epoch 12: val_loss did not improve from 0.17059
# 29/29 [==============================] - 56s 2s/step - loss: 0.1394 - accuracy: 0.9478 - val_loss: 0.1712 - val_accuracy: 0.9196
# Epoch 13/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1084 - accuracy: 0.9587
# Epoch 13: val_loss improved from 0.17059 to 0.14714, saving model to MobileNet_Goat_model_best.h5
# 29/29 [==============================] - 59s 2s/step - loss: 0.1084 - accuracy: 0.9587 - val_loss: 0.1471 - val_accuracy: 0.9464
# Epoch 14/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9348
# Epoch 14: val_loss did not improve from 0.14714
# 29/29 [==============================] - 56s 2s/step - loss: 0.1401 - accuracy: 0.9348 - val_loss: 0.1648 - val_accuracy: 0.9375
# Epoch 15/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1452 - accuracy: 0.9457
# Epoch 15: val_loss did not improve from 0.14714
# 29/29 [==============================] - 56s 2s/step - loss: 0.1452 - accuracy: 0.9457 - val_loss: 0.2476 - val_accuracy: 0.9107
# Epoch 16/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1770 - accuracy: 0.9435
# Epoch 16: val_loss did not improve from 0.14714
# 29/29 [==============================] - 61s 2s/step - loss: 0.1770 - accuracy: 0.9435 - val_loss: 0.1693 - val_accuracy: 0.9375
# Epoch 17/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9500
# Epoch 17: val_loss did not improve from 0.14714
# 29/29 [==============================] - 60s 2s/step - loss: 0.1400 - accuracy: 0.9500 - val_loss: 0.2863 - val_accuracy: 0.9286
# Epoch 18/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.9591
# Epoch 18: val_loss did not improve from 0.14714
# 29/29 [==============================] - 57s 2s/step - loss: 0.1164 - accuracy: 0.9591 - val_loss: 0.2041 - val_accuracy: 0.9107
# Epoch 19/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9674
# Epoch 19: val_loss improved from 0.14714 to 0.12218, saving model to MobileNet_Goat_model_best.h5
# 29/29 [==============================] - 60s 2s/step - loss: 0.0676 - accuracy: 0.9674 - val_loss: 0.1222 - val_accuracy: 0.9464
# Epoch 20/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0922 - accuracy: 0.9717
# Epoch 20: val_loss did not improve from 0.12218
# 29/29 [==============================] - 57s 2s/step - loss: 0.0922 - accuracy: 0.9717 - val_loss: 0.1960 - val_accuracy: 0.9286
# Epoch 21/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0827 - accuracy: 0.9652
# Epoch 21: val_loss did not improve from 0.12218
# 29/29 [==============================] - 57s 2s/step - loss: 0.0827 - accuracy: 0.9652 - val_loss: 0.2223 - val_accuracy: 0.9375
# Epoch 22/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9674
# Epoch 22: val_loss did not improve from 0.12218
# 29/29 [==============================] - 57s 2s/step - loss: 0.0868 - accuracy: 0.9674 - val_loss: 0.1360 - val_accuracy: 0.9286
# Epoch 23/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9761
# Epoch 23: val_loss did not improve from 0.12218
# 29/29 [==============================] - 58s 2s/step - loss: 0.0928 - accuracy: 0.9761 - val_loss: 0.1228 - val_accuracy: 0.9375
# Epoch 24/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9543
# Epoch 24: val_loss did not improve from 0.12218
# 29/29 [==============================] - 57s 2s/step - loss: 0.1169 - accuracy: 0.9543 - val_loss: 0.2504 - val_accuracy: 0.9018
# Epoch 25/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.9739
# Epoch 25: val_loss did not improve from 0.12218
# 29/29 [==============================] - 57s 2s/step - loss: 0.0706 - accuracy: 0.9739 - val_loss: 0.1924 - val_accuracy: 0.9375
# Epoch 26/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1143 - accuracy: 0.9565
# Epoch 26: val_loss did not improve from 0.12218
# 29/29 [==============================] - 58s 2s/step - loss: 0.1143 - accuracy: 0.9565 - val_loss: 0.1555 - val_accuracy: 0.9375
# Epoch 27/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0797 - accuracy: 0.9739
# Epoch 27: val_loss did not improve from 0.12218
# 29/29 [==============================] - 56s 2s/step - loss: 0.0797 - accuracy: 0.9739 - val_loss: 0.1387 - val_accuracy: 0.9286
# Epoch 28/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9674
# Epoch 28: val_loss did not improve from 0.12218
# 29/29 [==============================] - 56s 2s/step - loss: 0.0851 - accuracy: 0.9674 - val_loss: 0.1579 - val_accuracy: 0.9464
# Epoch 29/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9761
# Epoch 29: val_loss did not improve from 0.12218
# 29/29 [==============================] - 59s 2s/step - loss: 0.0609 - accuracy: 0.9761 - val_loss: 0.2048 - val_accuracy: 0.9286
# Epoch 30/50
# 29/29 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9609
# Epoch 30: val_loss did not improve from 0.12218
# 29/29 [==============================] - 56s 2s/step - loss: 0.1044 - accuracy: 0.9609 - val_loss: 0.1247 - val_accuracy: 0.9464
# Epoch 31/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9739
# Epoch 31: val_loss improved from 0.12218 to 0.11171, saving model to MobileNet_Goat_model_best.h5
# 29/29 [==============================] - 59s 2s/step - loss: 0.0584 - accuracy: 0.9739 - val_loss: 0.1117 - val_accuracy: 0.9554
# Epoch 32/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9739
# Epoch 32: val_loss did not improve from 0.11171
# 29/29 [==============================] - 56s 2s/step - loss: 0.0575 - accuracy: 0.9739 - val_loss: 0.1148 - val_accuracy: 0.9554
# Epoch 33/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0951 - accuracy: 0.9674
# Epoch 33: val_loss did not improve from 0.11171
# 29/29 [==============================] - 56s 2s/step - loss: 0.0951 - accuracy: 0.9674 - val_loss: 0.1562 - val_accuracy: 0.9375
# Epoch 34/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.9717
# Epoch 34: val_loss did not improve from 0.11171
# 29/29 [==============================] - 57s 2s/step - loss: 0.0724 - accuracy: 0.9717 - val_loss: 0.1175 - val_accuracy: 0.9643
# Epoch 35/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.9720
# Epoch 35: val_loss did not improve from 0.11171
# 29/29 [==============================] - 57s 2s/step - loss: 0.0902 - accuracy: 0.9720 - val_loss: 0.1649 - val_accuracy: 0.9554
# Epoch 36/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0861 - accuracy: 0.9783
# Epoch 36: val_loss did not improve from 0.11171
# 29/29 [==============================] - 56s 2s/step - loss: 0.0861 - accuracy: 0.9783 - val_loss: 0.1579 - val_accuracy: 0.9375
# Epoch 37/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9717
# Epoch 37: val_loss did not improve from 0.11171
# 29/29 [==============================] - 57s 2s/step - loss: 0.0841 - accuracy: 0.9717 - val_loss: 0.1691 - val_accuracy: 0.9375
# Epoch 38/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9826
# Epoch 38: val_loss did not improve from 0.11171
# 29/29 [==============================] - 57s 2s/step - loss: 0.0456 - accuracy: 0.9826 - val_loss: 0.2883 - val_accuracy: 0.9375
# Epoch 39/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9870
# Epoch 39: val_loss did not improve from 0.11171
# 29/29 [==============================] - 56s 2s/step - loss: 0.0423 - accuracy: 0.9870 - val_loss: 0.1197 - val_accuracy: 0.9464
# Epoch 40/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9804
# Epoch 40: val_loss did not improve from 0.11171
# 29/29 [==============================] - 57s 2s/step - loss: 0.0419 - accuracy: 0.9804 - val_loss: 0.1316 - val_accuracy: 0.9464
# Epoch 41/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9848
# Epoch 41: val_loss improved from 0.11171 to 0.10789, saving model to MobileNet_Goat_model_best.h5
# 29/29 [==============================] - 58s 2s/step - loss: 0.0426 - accuracy: 0.9848 - val_loss: 0.1079 - val_accuracy: 0.9643
# Epoch 42/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9783
# Epoch 42: val_loss did not improve from 0.10789
# 29/29 [==============================] - 57s 2s/step - loss: 0.0642 - accuracy: 0.9783 - val_loss: 0.2288 - val_accuracy: 0.9286
# Epoch 43/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9652
# Epoch 43: val_loss did not improve from 0.10789
# 29/29 [==============================] - 56s 2s/step - loss: 0.0719 - accuracy: 0.9652 - val_loss: 0.1494 - val_accuracy: 0.9464
# Epoch 44/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9696
# Epoch 44: val_loss did not improve from 0.10789
# 29/29 [==============================] - 56s 2s/step - loss: 0.0599 - accuracy: 0.9696 - val_loss: 0.2456 - val_accuracy: 0.9375
# Epoch 45/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9784
# Epoch 45: val_loss did not improve from 0.10789
# 29/29 [==============================] - 57s 2s/step - loss: 0.0560 - accuracy: 0.9784 - val_loss: 0.1737 - val_accuracy: 0.9554
# Epoch 46/50
# 29/29 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9804\Stopped, Akurasi mencapai 98%
#
# Epoch 46: val_loss improved from 0.10789 to 0.07751, saving model to MobileNet_Goat_model_best.h5
# 29/29 [==============================] - 58s 2s/step - loss: 0.0546 - accuracy: 0.9804 - val_loss: 0.0775 - val_accuracy: 0.9643

# %%
train_accuracy = history_mobileNet.history['accuracy']
val_accuracy = history_mobileNet.history['val_accuracy']
train_loss = history_mobileNet.history['loss']
val_loss= history_mobileNet.history['val_loss']

plt.figure(figsize=(16, 8))

# Cek hasil akurasi
plt.subplot(1, 2, 1)
plt.plot(train_accuracy, label='Training Accuracy', color='#185fad')
plt.plot(val_accuracy, label='Validation Accuracy', color='orange')

plt.title('Training and Validation Accuracy by Epoch', fontsize = 18)
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Mean-Square-Error', fontsize = 18)
plt.xticks(range(0,16,20), range(0,16,20))

plt.legend(fontsize = 18);

plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Training Loss', color='#185fad')
plt.plot(val_loss, label='Validation Loss', color='orange')

plt.title('Training and Validation Loss by Epoch', fontsize = 18)
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Mean-Square-Error', fontsize = 18)
plt.xticks(range(0,16,20), range(0,16,20))


plt.legend(fontsize = 18)

# %%
# Predict the label of the test_images
import numpy as np
pred = mobileNet_model.predict(validasi_data)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_data.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 15 predictions: {pred[:15]}')
# Out:
# 8/8 [==============================] - 8s 915ms/step
# The first 15 predictions: ['Pinkeye Goat', 'Healthy Goat', 'Pinkeye Goat', 'Healthy Goat', 'Pinkeye Goat', 'Healthy Goat', 'Pinkeye Goat', 'Healthy Goat', 'Pinkeye Goat', 'Pinkeye Goat', 'Pinkeye Goat', 'Healthy Goat', 'Pinkeye Goat', 'Healthy Goat', 'Pinkeye Goat']

# %%
#Plot the confusion matrix. Set Normalize = True/False

def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(20,20))

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

#Print the Target names
from sklearn.metrics import classification_report, confusion_matrix
import itertools 
#shuffle=False

target_names = []
for key in validasi_data.class_indices:
    target_names.append(key)

# print(target_names)

#Confution Matrix 

Y_pred = mobileNet_model.predict_generator(validasi_data)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm = confusion_matrix(validasi_data.classes, y_pred)
plot_confusion_matrix(cm, target_names, title='Confusion Matrix')

#Print Classification Report
print('Classification Report')
print(classification_report(validasi_data.classes, y_pred, target_names=target_names))
# Out:
# C:\Users\Fenny Puspitasari\AppData\Local\Temp\ipykernel_4308\385079297.py:47: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = mobileNet_model.predict_generator(validasi_data)
# Confusion Matrix
# Normalized confusion matrix
# Classification Report
#               precision    recall  f1-score   support
#
# Healthy Goat       0.96      0.94      0.95        49
# Pinkeye Goat       0.96      0.97      0.96        70
#
#     accuracy                           0.96       119
#    macro avg       0.96      0.96      0.96       119
# weighted avg       0.96      0.96      0.96       119

# %%
# Display some pictures of the dataset with their labels and the predictions
fig, axes = plt.subplots(nrows=7, ncols=5, figsize=(20, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(validasi_df.Filepath.iloc[i]))
    ax.set_title(f"True: {validasi_df.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_keras_model(mobileNet_model)
tflite_model = converter.convert()

with open('MobileNet_Goat_model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\FENNYP~1\AppData\Local\Temp\tmpb34xjd2q\assets
# INFO:tensorflow:Assets written to: C:\Users\FENNYP~1\AppData\Local\Temp\tmpb34xjd2q\assets
