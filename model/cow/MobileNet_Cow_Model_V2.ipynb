# %%
import os
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
import seaborn as sns

# %%
#pinkey cow
folder_path = (r'D:\Kampus Merdeka\Documentation\Cow\train\Pinkeye Cow')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#healthy cow
folder_path = (r'D:\Kampus Merdeka\Documentation\Cow\train\Healthy Cow')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#cek label
image_dir = Path(r'D:\Kampus Merdeka\Documentation\Cow\train')

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index
image_df = image_df.sample(frac=1).reset_index(drop = True)

# Show the result
image_df.head(2)
# Out:
#                                             Filepath        Label
# 0  D:\Kampus Merdeka\Documentation\Cow\train\Heal...  Healthy Cow
# 1  D:\Kampus Merdeka\Documentation\Cow\train\Pink...  Pinkeye Cow

# %%
# Display some pictures of the dataset with their labels

fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[i]))
    ax.set_title(image_df.Label[i])
plt.tight_layout()
plt.show()

# %%
#Shuffle
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
# Separate in train and test data
train_df, validasi_df = train_test_split(image_df, train_size=0.8, shuffle=True, random_state=1)

# %%
from keras import Model, Input
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
from keras import layers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
# %matplotlib inline

# %%
input_shape = (180,180,3)
model_input = Input(shape=input_shape)

mobileNet = MobileNetV2(input_shape=input_shape, 
                        input_tensor=model_input, 
                        include_top=False, 
                        weights="imagenet")

for layer in mobileNet.layers:
    layer.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
#data generator
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest',
    brightness_range=[0.8, 1.2],
    horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)
                                   
train_data = train_datagen.flow_from_dataframe(dataframe=train_df,
                                          x_col='Filepath',
                                          y_col='Label',
                                         seed=0,
                                         target_size=(180,180),
                                         batch_size=32,
                                         shuffle=True,
                                         class_mode = 'categorical',
                                        subset='training',
                                         )

validasi_data = val_datagen.flow_from_dataframe(dataframe=validasi_df,
                                        x_col='Filepath',
                                        y_col='Label',
                                         seed=0,
                                         target_size=(180,180),
                                         batch_size=32,
                                         shuffle=False,
                                         class_mode = 'categorical',
                                         )
# Out:
# Found 435 validated image filenames belonging to 2 classes.
# Found 109 validated image filenames belonging to 2 classes.

# %%
x_mobileNet = mobileNet.output
# Flatten 
x_mobileNet = Flatten()(x_mobileNet)
# Add a fully connected layer with 512 hidden units and ReLU activation
x_mobileNet = Dense(512, activation='relu')(x_mobileNet)
# Add a dropout rate of 0.5
x_mobileNet = Dropout(0.2)(x_mobileNet)
# Add a final softmax layer for classification
x_mobileNet = Dense(2, activation='softmax')(x_mobileNet)

# Configure and compile the model
mobileNet_model = Model(model_input, x_mobileNet)
optimizer = Adam(lr=1e-5)
mobileNet_model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# C:\Users\Fenny Puspitasari\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# ModelCheckpoint callback
checkpoint_callback = ModelCheckpoint('MobileNet_Cow_model_V2_best.h5',
                                      save_best_only=True,
                                      monitor='val_loss',
                                      mode='min', verbose=1)

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss') < 0.1 and logs.get('val_loss') < 0.1):
      print("\Stopped, Akurasi mencapai 98%")
      self.model.stop_training = True;

# %%
callbacks = myCallback()

# Fit the model
history_mobileNet = mobileNet_model.fit(
    train_data,
    validation_data=validasi_data,
    steps_per_epoch=train_data.n//32,
    validation_steps=validasi_data.n//32,
    batch_size=32,
    epochs=50,
    callbacks=[callbacks, checkpoint_callback])
# Out:
# Epoch 1/50
# 13/13 [==============================] - ETA: 0s - loss: 1.1095 - accuracy: 0.5608
# Epoch 1: val_loss improved from inf to 0.57450, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 13s 851ms/step - loss: 1.1095 - accuracy: 0.5608 - val_loss: 0.5745 - val_accuracy: 0.7604
# Epoch 2/50
# 13/13 [==============================] - ETA: 0s - loss: 0.5033 - accuracy: 0.7965
# Epoch 2: val_loss improved from 0.57450 to 0.44754, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 11s 809ms/step - loss: 0.5033 - accuracy: 0.7965 - val_loss: 0.4475 - val_accuracy: 0.7917
# Epoch 3/50
# 13/13 [==============================] - ETA: 0s - loss: 0.4712 - accuracy: 0.8164
# Epoch 3: val_loss improved from 0.44754 to 0.42594, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 10s 807ms/step - loss: 0.4712 - accuracy: 0.8164 - val_loss: 0.4259 - val_accuracy: 0.8021
# Epoch 4/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3978 - accuracy: 0.8362
# Epoch 4: val_loss improved from 0.42594 to 0.38955, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 11s 809ms/step - loss: 0.3978 - accuracy: 0.8362 - val_loss: 0.3895 - val_accuracy: 0.8438
# Epoch 5/50
# 13/13 [==============================] - ETA: 0s - loss: 0.4164 - accuracy: 0.8362
# Epoch 5: val_loss improved from 0.38955 to 0.36310, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 10s 795ms/step - loss: 0.4164 - accuracy: 0.8362 - val_loss: 0.3631 - val_accuracy: 0.8333
# Epoch 6/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3489 - accuracy: 0.8561
# Epoch 6: val_loss improved from 0.36310 to 0.36208, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 11s 815ms/step - loss: 0.3489 - accuracy: 0.8561 - val_loss: 0.3621 - val_accuracy: 0.8333
# Epoch 7/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3262 - accuracy: 0.8759
# Epoch 7: val_loss improved from 0.36208 to 0.31223, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 11s 810ms/step - loss: 0.3262 - accuracy: 0.8759 - val_loss: 0.3122 - val_accuracy: 0.8542
# Epoch 8/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3377 - accuracy: 0.8586
# Epoch 8: val_loss did not improve from 0.31223
# 13/13 [==============================] - 10s 734ms/step - loss: 0.3377 - accuracy: 0.8586 - val_loss: 0.3195 - val_accuracy: 0.8854
# Epoch 9/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3306 - accuracy: 0.8685
# Epoch 9: val_loss did not improve from 0.31223
# 13/13 [==============================] - 10s 742ms/step - loss: 0.3306 - accuracy: 0.8685 - val_loss: 0.3558 - val_accuracy: 0.8229
# Epoch 10/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2785 - accuracy: 0.8834
# Epoch 10: val_loss did not improve from 0.31223
# 13/13 [==============================] - 10s 738ms/step - loss: 0.2785 - accuracy: 0.8834 - val_loss: 0.3561 - val_accuracy: 0.8333
# Epoch 11/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2562 - accuracy: 0.8958
# Epoch 11: val_loss did not improve from 0.31223
# 13/13 [==============================] - 10s 739ms/step - loss: 0.2562 - accuracy: 0.8958 - val_loss: 0.3192 - val_accuracy: 0.8438
# Epoch 12/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2683 - accuracy: 0.8883
# Epoch 12: val_loss did not improve from 0.31223
# 13/13 [==============================] - 10s 740ms/step - loss: 0.2683 - accuracy: 0.8883 - val_loss: 0.3196 - val_accuracy: 0.8333
# Epoch 13/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2189 - accuracy: 0.9057
# Epoch 13: val_loss improved from 0.31223 to 0.27973, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 11s 834ms/step - loss: 0.2189 - accuracy: 0.9057 - val_loss: 0.2797 - val_accuracy: 0.8542
# Epoch 14/50
# 13/13 [==============================] - ETA: 0s - loss: 0.1764 - accuracy: 0.9429
# Epoch 14: val_loss improved from 0.27973 to 0.26747, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 10s 784ms/step - loss: 0.1764 - accuracy: 0.9429 - val_loss: 0.2675 - val_accuracy: 0.8542
# Epoch 15/50
# 13/13 [==============================] - ETA: 0s - loss: 0.1922 - accuracy: 0.9256
# Epoch 15: val_loss did not improve from 0.26747
# 13/13 [==============================] - 10s 739ms/step - loss: 0.1922 - accuracy: 0.9256 - val_loss: 0.2820 - val_accuracy: 0.8438
# Epoch 16/50
# 13/13 [==============================] - ETA: 0s - loss: 0.1978 - accuracy: 0.9132
# Epoch 16: val_loss improved from 0.26747 to 0.26571, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 10s 798ms/step - loss: 0.1978 - accuracy: 0.9132 - val_loss: 0.2657 - val_accuracy: 0.9062
# Epoch 17/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2437 - accuracy: 0.8933
# Epoch 17: val_loss did not improve from 0.26571
# 13/13 [==============================] - 10s 730ms/step - loss: 0.2437 - accuracy: 0.8933 - val_loss: 0.2682 - val_accuracy: 0.8958
# Epoch 18/50
# 13/13 [==============================] - ETA: 0s - loss: 0.1737 - accuracy: 0.9256
# Epoch 18: val_loss did not improve from 0.26571
# 13/13 [==============================] - 10s 737ms/step - loss: 0.1737 - accuracy: 0.9256 - val_loss: 0.3584 - val_accuracy: 0.8333
# Epoch 19/50
# 13/13 [==============================] - ETA: 0s - loss: 0.1752 - accuracy: 0.9231
# Epoch 19: val_loss did not improve from 0.26571
# 13/13 [==============================] - 10s 742ms/step - loss: 0.1752 - accuracy: 0.9231 - val_loss: 0.2759 - val_accuracy: 0.8646
# Epoch 20/50
# 13/13 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9280
# Epoch 20: val_loss improved from 0.26571 to 0.23734, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 10s 799ms/step - loss: 0.1842 - accuracy: 0.9280 - val_loss: 0.2373 - val_accuracy: 0.9167
# Epoch 21/50
# 13/13 [==============================] - ETA: 0s - loss: 0.1901 - accuracy: 0.9206
# Epoch 21: val_loss improved from 0.23734 to 0.22657, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 10s 794ms/step - loss: 0.1901 - accuracy: 0.9206 - val_loss: 0.2266 - val_accuracy: 0.8958
# Epoch 22/50
# 13/13 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9330
# Epoch 22: val_loss did not improve from 0.22657
# 13/13 [==============================] - 10s 757ms/step - loss: 0.1408 - accuracy: 0.9330 - val_loss: 0.2725 - val_accuracy: 0.8854
# Epoch 23/50
# 13/13 [==============================] - ETA: 0s - loss: 0.1595 - accuracy: 0.9454
# Epoch 23: val_loss improved from 0.22657 to 0.20007, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 11s
val_loss did not improve from 0.16632
# 13/13 [==============================] - 10s 760ms/step - loss: 0.1114 - accuracy: 0.9628 - val_loss: 0.1764 - val_accuracy: 0.9375
# Epoch 43/50
# 13/13 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9851
# Epoch 43: val_loss did not improve from 0.16632
# 13/13 [==============================] - 10s 760ms/step - loss: 0.0540 - accuracy: 0.9851 - val_loss: 0.2074 - val_accuracy: 0.9271
# Epoch 44/50
# 13/13 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9752
# Epoch 44: val_loss did not improve from 0.16632
# 13/13 [==============================] - 10s 758ms/step - loss: 0.0845 - accuracy: 0.9752 - val_loss: 0.2223 - val_accuracy: 0.9167
# Epoch 45/50
# 13/13 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9663
# Epoch 45: val_loss did not improve from 0.16632
# 13/13 [==============================] - 10s 765ms/step - loss: 0.1017 - accuracy: 0.9663 - val_loss: 0.2045 - val_accuracy: 0.9167
# Epoch 46/50
# 13/13 [==============================] - ETA: 0s - loss: 0.1161 - accuracy: 0.9479
# Epoch 46: val_loss did not improve from 0.16632
# 13/13 [==============================] - 10s 746ms/step - loss: 0.1161 - accuracy: 0.9479 - val_loss: 0.1787 - val_accuracy: 0.9479
# Epoch 47/50
# 13/13 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9702
# Epoch 47: val_loss improved from 0.16632 to 0.16536, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 10s 807ms/step - loss: 0.0845 - accuracy: 0.9702 - val_loss: 0.1654 - val_accuracy: 0.9583
# Epoch 48/50
# 13/13 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9851
# Epoch 48: val_loss improved from 0.16536 to 0.16150, saving model to MobileNet_Cow_model_V2_best.h5
# 13/13 [==============================] - 11s 809ms/step - loss: 0.0519 - accuracy: 0.9851 - val_loss: 0.1615 - val_accuracy: 0.9271
# Epoch 49/50
# 13/13 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9688
# Epoch 49: val_loss did not improve from 0.16150
# 13/13 [==============================] - 10s 759ms/step - loss: 0.0637 - accuracy: 0.9688 - val_loss: 0.1622 - val_accuracy: 0.9479
# Epoch 50/50
# 13/13 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9677
# Epoch 50: val_loss did not improve from 0.16150
# 13/13 [==============================] - 10s 753ms/step - loss: 0.0755 - accuracy: 0.9677 - val_loss: 0.1807 - val_accuracy: 0.9271

# %%
train_accuracy = history_mobileNet.history['accuracy']
val_accuracy = history_mobileNet.history['val_accuracy']
train_loss = history_mobileNet.history['loss']
val_loss= history_mobileNet.history['val_loss']

plt.figure(figsize=(16, 8))

# Cek hasil akurasi
plt.subplot(1, 2, 1)
plt.plot(train_accuracy, label='Training Accuracy', color='#185fad')
plt.plot(val_accuracy, label='Validation Accuracy', color='orange')

plt.title('Training and Validation Accuracy by Epoch', fontsize = 18)
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Mean-Square-Error', fontsize = 18)
plt.xticks(range(0,16,20), range(0,16,20))

plt.legend(fontsize = 18);

plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Training Loss', color='#185fad')
plt.plot(val_loss, label='Validation Loss', color='orange')

plt.title('Training and Validation Loss by Epoch', fontsize = 18)
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Mean-Square-Error', fontsize = 18)
plt.xticks(range(0,16,20), range(0,16,20))


plt.legend(fontsize = 18)

# %%
# Predict the label of the test_images
import numpy as np
pred = mobileNet_model.predict(validasi_data)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_data.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 15 predictions: {pred[:15]}')
# Out:
# 4/4 [==============================] - 2s 302ms/step
# The first 15 predictions: ['Pinkeye Cow', 'Healthy Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Healthy Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Pinkeye Cow', 'Pinkeye Cow']

# %%
#Plot the confusion matrix. Set Normalize = True/False

def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(20,20))

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

#Print the Target names
from sklearn.metrics import classification_report, confusion_matrix
import itertools 
#shuffle=False

target_names = []
for key in validasi_data.class_indices:
    target_names.append(key)

# print(target_names)

#Confution Matrix 

Y_pred = mobileNet_model.predict_generator(validasi_data)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm = confusion_matrix(validasi_data.classes, y_pred)
plot_confusion_matrix(cm, target_names, title='Confusion Matrix')

#Print Classification Report
print('Classification Report')
print(classification_report(validasi_data.classes, y_pred, target_names=target_names))
# Out:
# C:\Users\Fenny Puspitasari\AppData\Local\Temp\ipykernel_1464\385079297.py:47: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = mobileNet_model.predict_generator(validasi_data)
# Confusion Matrix
# Normalized confusion matrix
# Classification Report
#               precision    recall  f1-score   support
#
#  Healthy Cow       0.91      0.89      0.90        35
#  Pinkeye Cow       0.95      0.96      0.95        74
#
#     accuracy                           0.94       109
#    macro avg       0.93      0.92      0.93       109
# weighted avg       0.94      0.94      0.94       109

# %%
# Display some pictures of the dataset with their labels and the predictions
fig, axes = plt.subplots(nrows=7, ncols=5, figsize=(20, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(validasi_df.Filepath.iloc[i]))
    ax.set_title(f"True: {validasi_df.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_keras_model(mobileNet_model)
tflite_model = converter.convert()

with open('MobileNet_Cow_V2_model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\FENNYP~1\AppData\Local\Temp\tmpzfdnvmfh\assets
# INFO:tensorflow:Assets written to: C:\Users\FENNYP~1\AppData\Local\Temp\tmpzfdnvmfh\assets
